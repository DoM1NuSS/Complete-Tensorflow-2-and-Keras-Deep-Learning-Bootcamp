# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
x = [0,1,2]
y = [100,200,300]
plt.plot(x,y)

# %%
housing = pd.DataFrame({'rooms':[1,1,2,2,2,3,3,3],
                       'price':[100,120,190,200,230,310,330,305]})

# %%
housing
# Out:
#    rooms  price
# 0      1    100
# 1      1    120
# 2      2    190
# 3      2    200
# 4      2    230
# 5      3    310
# 6      3    330
# 7      3    305

# %%
plt.title('Rooms vs Price')
plt.xlabel('Rooms')
plt.ylabel('price')
plt.scatter(housing['rooms'], housing['price'])

# %%
df = pd.read_csv("C:/Users/Windows/Desktop/SauSau/TensorFlow/Tensorflow-Bootcamp-master/Tf kurs/TF_2_Notebooks_and_Data/DATA/heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
plt.figure(figsize=(5,5)) #Podesavanje velicine plota
sns.distplot(df['age'])
# Out:
# C:\Users\Windows\AppData\Local\Temp\ipykernel_16392\3920959453.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
sns.countplot(x='cp', data=df, hue='sex')
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
#BOX PLOT
""""
Pokazuje distribuciju unakrsno nekoliko kategorija
Deli podatke u 4 jednaka dela
Interquartile Range (IQR) izmedju Q1 i Q3
Q1 je 25th procenat
Q3 je 75th procenat
Pokazuje jasno koliko podatak postoji u sredini oko medijane
Minimum je Q1 - 1.5* IQR - outlier
Maximum je Q3 + 1.5* IQR - outlier
"""""
# Out:
# '"\nPokazuje distribuciju unakrsno nekoliko kategorija\nDeli podatke u 4 jednaka dela\nInterquartile Range (IQR) izmedju Q1 i Q3\nQ1 je 25th procenat\nQ3 je 75th procenat\nPokazuje jasno koliko podatak postoji u sredini oko medijane\nMinimum je Q1 - 1.5* IQR - outlier\nMaximum je Q3 + 1.5* IQR - outlier\n'

# %%
sns.boxplot(x='target', y='thalach', data=df, hue='sex')
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
sns.scatterplot(x='chol', y='trestbps', data=df, size='age',hue='', palette='Dark2')
# Out:
# C:\Users\Windows\AppData\Local\Temp\ipykernel_16392\1240304376.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='chol', y='trestbps', data=df, size='age', palette='Dark2')
# <Axes: xlabel='chol', ylabel='trestbps'>

# %%
iris = pd.read_csv("TF_2_Notebooks_and_Data/DATA/iris.csv")

# %%
sns.pairplot(data=iris)
